# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# %%
df = pd.read_csv('./total_st_students-counselors.csv')

# %%
df['Result'] = df['TOTSTU']/df['TOTCOU']
ratio = df.sort_values('Result', ascending=False)
ratio
# Out:
#    STABR                                 STATENAME    TOTCOU   TOTSTU  \
# 2     AZ                                   ARIZONA   1228.01  1109040
# 22    MI                                  MICHIGAN   2063.60  1536231
# 4     CA                                CALIFORNIA   8799.50  6226737
# 23    MN                                 MINNESOTA   1245.94   864384
# 44    UT                                      UTAH    952.07   647870
# 13    IL                                  ILLINOIS   3011.00  2041779
# 12    ID                                     IDAHO    500.11   292277
# 55    PR                               PUERTO RICO    659.00   379818
# 14    IN                                   INDIANA   1963.87  1046757
# 8     DC                      DISTRICT OF COLUMBIA    171.58    88200
# 37    OR                                    OREGON   1127.14   576407
# 47    WA                                WASHINGTON   2130.62  1087030
# ...

# %%
ax = ratio.sort_values(
    'Result', ascending=False
).head(5).plot(y="Result", kind="bar", figsize=(10,7),
               color='r', rot=0, fontsize=12, legend=False
)
for p in ax.patches: ax.annotate(
    np.round(p.get_height(),decimals=1
            ), (p.get_x()+p.get_width()/2., p.get_height()), 
    ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=12)
plt.xlabel(
    "Source: National Center for Education Statistics", fontsize=12
)
plt.hlines(y=250, xmin=0, xmax=6, color='b')
ax.xaxis.set_label_coords(.7, -0.1)
plt.suptitle('States with the highest counselor-to-student ratio for 2015 - 2016', y=.93, fontsize=16)
plt.xticks(np.arange(5), ('Arizona', 'Michigan', 'California', 'Minnesota', 'Utah'), fontsize=14)
plt.style.use('seaborn-darkgrid')
plt.savefig('./ratio.svg', bbbox_inches='tight')
plt.show()
